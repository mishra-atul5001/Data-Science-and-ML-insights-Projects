# %% [markdown]
# # Identifying Stationary Time Series - ACF and PACF

# %% [markdown]
# As discussed earlier, there are some specialised tests that can help you distinguish white noise from an ordinary stationary series. These tests are necessary because visually, a stationary time series does not really look very different from white noise.
#
# One such test is called an **Autocorrelation function (ACF)**.

# %% [markdown]
# ### ACF Test

# %% [markdown]
# One of the most important tests to check if a time series is stationary is the ACF Test. It helps us to identify whether a series has any autoregressive nature in it or not.

# %%
# Generate a sequence of Gaussian random numbers and
# convert the sequence into a time-series object
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# create white noise series
noise = np.random.normal(0, 1, 1000)

# Plot the series
plt.plot(noise)
plt.xlabel("Time")
plt.ylabel("Noise")
plt.show()

# Compute and plot the ACF for the time series
import statsmodels.graphics.tsaplots as tsa
tsa.plot_acf(noise, lags=50)
plt.show()

# Compute and plot the ACF for the time series
tsa.plot_pacf(noise, lags=50)
plt.show()
