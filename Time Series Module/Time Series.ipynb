# %%
# Importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Loading the dataset
# Keep the dataset in the same location as the notebook file. 
# If not, then specify the correct address whille loading the file.
df1 = pd.read_csv("exchange-rate-twi.csv")
df1.head()

#Plotting the series
plt.figure(num=None, figsize=(12, 6), dpi=80, facecolor='w', edgecolor='k')
df1.iloc[:,1].plot()
plt.xlabel('Month')
plt.ylabel('Exchange Rate TWI')
plt.show();

# %%
for i in df1['Month']:
    df1['globalpred'] = 111.82-0.2178*i

# %%
df1.head()
# Out:
#    Month  Exchange Rate TWI  globalpred
# 0      1              100.0     45.6088
# 1      2               99.6     45.6088
# 2      3               99.4     45.6088
# 3      4               99.1     45.6088
# 4      5               99.2     45.6088

# %%
df1['localpred'] = df1['globalpred'] - df1['Exchange Rate TWI']

# %%
df1.sort_values(by = 'Month',ascending=False)
# Out:
#      Month  Exchange Rate TWI  globalpred  localpred
# 303    304               53.9     45.6088    -8.2912
# 302    303               51.0     45.6088    -5.3912
# 301    302               48.4     45.6088    -2.7912
# 300    301               48.5     45.6088    -2.8912
# 299    300               49.6     45.6088    -3.9912
# ..     ...                ...         ...        ...
# 4        5               99.2     45.6088   -53.5912
# 3        4               99.1     45.6088   -53.4912
# 2        3               99.4     45.6088   -53.7912
# 1        2               99.6     45.6088   -53.9912
# 0        1              100.0     45.6088   -54.3912
#
# [304 rows x 4 columns]

# %%
df1['localpred'][299]
# Out:
# -3.991199999999999
